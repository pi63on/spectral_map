# %%
import numpy as np

# %%
transfer = 'm3,24,m3,23,m3,22,m3,21,m3,20,m3,19,m3,18,m3,17,m3,16,m3,15,m3,14,m3,13,m3,12,m3,11,m3,10,m3,9,m3,8,m3,7,m3,6,m3,5,m3,4,m3,3,m3,2,m3,1,m3,0,m2,5,m2,4,m2,3,m2,2,m2,1,m2,0,m2,6,m2,7,m2,8,m2,9,m2,11,m2,10,m2,12,m2,13,m2,14,m2,15,m2,16,m2,17,m2,18,m2,19,m2,20,m2,21,m2,22,m2,24,m2,23,m2,25,m2,26,m2,27,m2,28,m2,29,m2,30,m2,31,m2,32,m2,33,m2,32,m2,34,m2,35,m2,36,m2,37,m2,38,m2,39,m2,40,m2,41,m2,42,m2,43,m2,44,m2,45,m2,46,m2,47,m2,48,m2,49,m2,50,m2,51,m2,52,m2,53,m2,54,m2,55,m2,56,m2,57,m2,58,m2,59,m2,60,m2,61,m2,62,m2,63,m2,64,m2,65,m2,66,m2,67,m2,68,m2,69,m2,71,m2,70,m2,72,m2,73,m2,74,m2,75,m2,76,m2,77,m2,78,m2,79,m3,0,m3,33,m3,32,m3,31,m3,30,m3,25,m3,30,m3,29,m3,28,m3,27,m3,26,m3,24,m3,23,m3,22,m3,21,m3,20,m3,19,m3,18,m3,17'

# %%
transfer_list = transfer.split(',')

# %%
transfer_list
# Out:
# ['m3',
#  '24',
#  'm3',
#  '23',
#  'm3',
#  '22',
#  'm3',
#  '21',
#  'm3',
#  '20',
#  'm3',
#  '19',
#  'm3',
#  '18',
#  'm3',
#  '17',
#  'm3',
#  '16',
#  'm3',
#  '15',
#  'm3',
#  '14',
#  'm3',
#  '13',
#  'm3',
#  '12',
#  'm3',
#  '11',
#  'm3',
#  '10',
#  'm3',
#  '9',
#  'm3',
#  '8',
#  'm3',
#  '7',
#  'm3',
#  '6',
#  'm3',
#  '5',
#  'm3',
#  '4',
#  'm3',
#  '3',
#  'm3',
#  '2',
#  'm3',
#  '1',
#  'm3',
#  '0',
#  'm2',
#  '5',
#  'm2',
#  '4',
#  'm2',
#  '3',
#  'm2',
#  '2',
#  'm2',
#  '1',
#  'm2',
#  '0',
#  'm2',
#  '6',
#  'm2',
#  '7',
#  'm2',
#  '8',
#  'm2',
#  '9',
#  'm2',
#  '11',
#  'm2',
#  '10',
#  'm2',
#  '12',
#  'm2',
#  '13',
#  'm2',
#  '14',
#  'm2',
#  '15',
#  'm2',
#  '16',
#  'm2',
#  '17',
#  'm2',
#  '18',
#  'm2',
#  '19',
#  'm2',
#  '20',
#  'm2',
#  '21',
#  'm2',
#  '22',
#  'm2',
#  '24',
#  'm2',
#  '23',
#  'm2',
#  '25',
#  'm2',
#  '26',
#  'm2',
#  '27',
#  'm2',
#  '28',
#  'm2',
#  '29',
#  'm2',
#  '30',
#  'm2',
# ...

# %%
del transfer_list[221]
del transfer_list[220]
del transfer_list[213]
del transfer_list[212]
del transfer_list[115]
del transfer_list[114]

# %%
for i, name in enumerate(transfer_list):
    print(i, name)
# Out:
# 0 m3
# 1 24
# 2 m3
# 3 23
# 4 m3
# 5 22
# 6 m3
# 7 21
# 8 m3
# 9 20
# 10 m3
# 11 19
# 12 m3
# 13 18
# 14 m3
# 15 17
# 16 m3
# 17 16
# 18 m3
# 19 15
# 20 m3
# 21 14
# 22 m3
# 23 13
# 24 m3
# 25 12
# 26 m3
# 27 11
# 28 m3
# 29 10
# 30 m3
# 31 9
# 32 m3
# 33 8
# 34 m3
# 35 7
# 36 m3
# 37 6
# 38 m3
# 39 5
# 40 m3
# 41 4
# 42 m3
# 43 3
# 44 m3
# 45 2
# 46 m3
# 47 1
# 48 m3
# 49 0
# 50 m2
# 51 5
# 52 m2
# 53 4
# 54 m2
# 55 3
# 56 m2
# 57 2
# 58 m2
# 59 1
# 60 m2
# 61 0
# 62 m2
# 63 6
# 64 m2
# 65 7
# 66 m2
# 67 8
# 68 m2
# 69 9
# 70 m2
# 71 11
# 72 m2
# 73 10
# 74 m2
# 75 12
# 76 m2
# 77 13
# 78 m2
# 79 14
# 80 m2
# 81 15
# 82 m2
# 83 16
# 84 m2
# 85 17
# 86 m2
# 87 18
# 88 m2
# 89 19
# 90 m2
# 91 20
# 92 m2
# 93 21
# 94 m2
# 95 22
# 96 m2
# 97 24
# 98 m2
# 99 23
# 100 m2
# 101 25
# 102 m2
# 103 26
# 104 m2
# 105 27
# 106 m2
# 107 28
# 108 m2
# 109 29
# 110 m2
# 111 30
# 112 m2
# 113 31
# 114 m2
# 115 33
# 116 m2
# 117 32
# 118 m2
# 119 34
# 120 m2
# 121 35
# 122 m2
# 123 36
# 124 m2
# ...

# %%
for i in range(243, 200, -1):
    print(i)
    if (i > 227):
        del transfer_list[i]
# Out:
# 243
# 242
# 241
# 240
# 239
# 238
# 237
# 236
# 235
# 234
# 233
# 232
# 231
# 230
# 229
# 228
# 227
# 226
# 225
# 224
# 223
# 222
# 221
# 220
# 219
# 218
# 217
# 216
# 215
# 214
# 213
# 212
# 211
# 210
# 209
# 208
# 207
# 206
# 205
# 204
# 203
# 202
# 201

# %%
transfer_list
# Out:
# ['m3',
#  '24',
#  'm3',
#  '23',
#  'm3',
#  '22',
#  'm3',
#  '21',
#  'm3',
#  '20',
#  'm3',
#  '19',
#  'm3',
#  '18',
#  'm3',
#  '17',
#  'm3',
#  '16',
#  'm3',
#  '15',
#  'm3',
#  '14',
#  'm3',
#  '13',
#  'm3',
#  '12',
#  'm3',
#  '11',
#  'm3',
#  '10',
#  'm3',
#  '9',
#  'm3',
#  '8',
#  'm3',
#  '7',
#  'm3',
#  '6',
#  'm3',
#  '5',
#  'm3',
#  '4',
#  'm3',
#  '3',
#  'm3',
#  '2',
#  'm3',
#  '1',
#  'm3',
#  '0',
#  'm2',
#  '5',
#  'm2',
#  '4',
#  'm2',
#  '3',
#  'm2',
#  '2',
#  'm2',
#  '1',
#  'm2',
#  '0',
#  'm2',
#  '6',
#  'm2',
#  '7',
#  'm2',
#  '8',
#  'm2',
#  '9',
#  'm2',
#  '11',
#  'm2',
#  '10',
#  'm2',
#  '12',
#  'm2',
#  '13',
#  'm2',
#  '14',
#  'm2',
#  '15',
#  'm2',
#  '16',
#  'm2',
#  '17',
#  'm2',
#  '18',
#  'm2',
#  '19',
#  'm2',
#  '20',
#  'm2',
#  '21',
#  'm2',
#  '22',
#  'm2',
#  '24',
#  'm2',
#  '23',
#  'm2',
#  '25',
#  'm2',
#  '26',
#  'm2',
#  '27',
#  'm2',
#  '28',
#  'm2',
#  '29',
#  'm2',
#  '30',
#  'm2',
# ...
