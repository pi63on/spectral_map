# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
data = pd.read_csv("m1/2025092922412660.csv", delimiter = '\t', skiprows=1)
x = data['wavelength']
y = data['intensity']

# %%
plt.rcParams.update({'font.size': 16})
COLOR = 'white'
mpl.rcParams['text.color'] = COLOR
mpl.rcParams['axes.labelcolor'] = COLOR
mpl.rcParams['xtick.color'] = COLOR
mpl.rcParams['ytick.color'] = COLOR
mpl.rcParams['axes.edgecolor'] = COLOR


fig, ax = plt.subplots(figsize=(10,7), facecolor = 'black')
plt.scatter(x,y, s = 1 , color = 'white' )
plt.plot(x,y, linewidth = 1 , color = 'white' , alpha = .1)
ax.set_yticklabels([])

ax.set_facecolor("black")
plt.xlabel("wavelength (nm)")

plt.tight_layout()
plt.savefig('m1_spektra/660.png')
