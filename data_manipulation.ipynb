# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("data.csv")
print(data)
# Out:
#              X          Y      time  video
# 0    17.121309  48.127902  16:48:49    0.0
# 1    17.121250  48.127908  16:48:50    1.0
# 2    17.121188  48.127913  16:48:51    2.0
# 3    17.121125  48.127917  16:48:52    3.0
# 4    17.120803  48.127924  16:48:57    8.0
# ..         ...        ...       ...    ...
# 693        NaN        NaN       NaN    NaN
# 694        NaN        NaN       NaN    NaN
# 695        NaN        NaN       NaN    NaN
# 696        NaN        NaN       NaN    NaN
# 697        NaN        NaN       NaN    NaN
#
# [698 rows x 4 columns]

# %%
data_cut = data.iloc[:676:10]
print(data_cut)
# Out:
#              X          Y      time  video
# 0    17.121309  48.127902  16:48:49    0.0
# 10   17.120352  48.127918  16:49:03   14.0
# 20   17.119627  48.127942  16:49:13   24.0
# 30   17.118855  48.127994  16:49:24   35.0
# 40   17.118176  48.128012  16:49:34   45.0
# ..         ...        ...       ...    ...
# 630  17.102673  48.139705  16:59:24  635.0
# 640  17.102106  48.139739  16:59:34  645.0
# 650  17.101435  48.139745  16:59:44  655.0
# 660  17.100686  48.139777  16:59:54  665.0
# 670  17.099967  48.139784  17:00:04  675.0
#
# [68 rows x 4 columns]

# %%
data_cut.to_csv("data_cut.csv")
